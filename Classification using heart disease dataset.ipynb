# %%
#import pandas
import pandas as pd
#import numpy
import numpy as np
#import matplotlib
import matplotlib.pyplot as plt
#import seaborn
import seaborn as sns

# %%
# use pandas to import csv file
df = pd.read_csv("D:\sem-6\DSPL\DSPL_LAB-main\Data_Set\Heart_main.csv")
# too see max columns
pd.set_option('display.max_columns',None)
# print dataframe
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke DiffWalking     Sex  \
# 0                No  16.60     Yes              No     No          No  Female
# 1                No  20.34      No              No    Yes          No  Female
# 2                No  26.58     Yes              No     No          No    Male
# 3                No  24.21      No              No     No          No  Female
# 4                No  23.71      No              No     No         Yes  Female
# ...             ...    ...     ...             ...    ...         ...     ...
# 319790          Yes  27.41     Yes              No     No         Yes    Male
# 319791           No  29.84     Yes              No     No          No    Male
# 319792           No  24.24      No              No     No          No  Female
# 319793           No  32.81      No              No     No          No  Female
# 319794           No  46.56      No              No     No          No  Female
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   DiffWalking       319795 non-null  object
#  6   Sex               319795 non-null  object
#  7   Diabetic          319795 non-null  object
#  8   PhysicalActivity  319795 non-null  object
#  9   GenHealth         319795 non-null  object
#  10  SleepTime         319795 non-null  int64
#  11  Asthma            319795 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 29.3+ MB

# %%
#New dataframe 
new_df = df
#Checking for null values 
print(new_df.isnull().sum()) 
print("Missing values distribution: ")
print(new_df.isnull().mean())
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# DiffWalking         0
# Sex                 0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# dtype: int64
# Missing values distribution:
# HeartDisease        0.0
# BMI                 0.0
# Smoking             0.0
# AlcoholDrinking     0.0
# Stroke              0.0
# DiffWalking         0.0
# Sex                 0.0
# Diabetic            0.0
# PhysicalActivity    0.0
# GenHealth           0.0
# SleepTime           0.0
# Asthma              0.0
# dtype: float64

# %%
#Replacing string values with integer 
new_df["Sex"].replace({"Male":"1", "Female":"0"}, inplace = True) 
print(new_df.head())
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke DiffWalking Sex Diabetic  \
# 0           No  16.60     Yes              No     No          No   0      Yes
# 1           No  20.34      No              No    Yes          No   0       No
# 2           No  26.58     Yes              No     No          No   1      Yes
# 3           No  24.21      No              No     No          No   0       No
# 4           No  23.71      No              No     No         Yes   0       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma
# 0              Yes  Very good          5    Yes
# 1              Yes  Very good          7     No
# 2              Yes       Fair          8    Yes
# 3               No       Good          6     No
# 4              Yes  Very good          8     No

# %%
new_df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke DiffWalking Sex  \
# 0                No  16.60     Yes              No     No          No   0
# 1                No  20.34      No              No    Yes          No   0
# 2                No  26.58     Yes              No     No          No   1
# 3                No  24.21      No              No     No          No   0
# 4                No  23.71      No              No     No         Yes   0
# ...             ...    ...     ...             ...    ...         ...  ..
# 319790          Yes  27.41     Yes              No     No         Yes   1
# 319791           No  29.84     Yes              No     No          No   1
# 319792           No  24.24      No              No     No          No   0
# 319793           No  32.81      No              No     No          No   0
# 319794           No  46.56      No              No     No          No   0
#
#        Diabetic PhysicalActivity  GenHealth  SleepTime Asthma
# ...

# %%
#Finding unique values in "Region" 
print(new_df["GenHealth"].unique())
# Out:
# ['Very good' 'Fair' 'Good' 'Poor' 'Excellent']

# %%
#Replacing string values with int
 
new_df['GenHealth'].replace({'Very good':'0','Fair':'1','Good':'2','Poor':' 3','Excellent':' 4'}, inplace = True)
print(new_df.head())
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke DiffWalking Sex Diabetic  \
# 0           No  16.60       1               0      0           0   0        1
# 1           No  20.34       0               0      1           0   0        0
# 2           No  26.58       1               0      0           0   1        1
# 3           No  24.21       0               0      0           0   0        0
# 4           No  23.71       0               0      0           1   0        0
#
#   PhysicalActivity GenHealth  SleepTime Asthma
# 0                1         0          5      1
# 1                1         0          7      0
# 2                1         1          8      1
# 3                0         2          6      0
# 4                1         0          8      0

# %%
new_df.drop("SleepTime", axis='columns')
new_df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke DiffWalking Sex  \
# 0                No  16.60       1               0      0           0   0
# 1                No  20.34       0               0      1           0   0
# 2                No  26.58       1               0      0           0   1
# 3                No  24.21       0               0      0           0   0
# 4                No  23.71       0               0      0           1   0
# ...             ...    ...     ...             ...    ...         ...  ..
# 319790          Yes  27.41       1               0      0           1   1
# 319791           No  29.84       1               0      0           0   1
# 319792           No  24.24       0               0      0           0   0
# 319793           No  32.81       0               0      0           0   0
# 319794           No  46.56       0               0      0           0   0
#
#        Diabetic PhysicalActivity GenHealth  SleepTime Asthma
# ...

# %%
#Replacing string values with integer 
new_df["Smoking"].replace({"Yes":"1", "No":"0"}, inplace = True) 
new_df["AlcoholDrinking"].replace({"Yes":"1", "No":"0"}, inplace = True) 
new_df["DiffWalking"].replace({"Yes":"1", "No":"0"}, inplace = True) 
new_df["Diabetic"].replace({"Yes":"1", "No":"0" ,"No, borderline diabetes": "2" , "Yes (during pregnancy)" : "3"}, inplace = True) 
new_df["PhysicalActivity"].replace({"Yes":"1", "No":"0"}, inplace = True) 
new_df["Asthma"].replace({"Yes":"1", "No":"0"}, inplace = True) 
new_df["Stroke"].replace({"Yes":"1", "No":"0"}, inplace = True) 

print(new_df.head())
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke DiffWalking Sex Diabetic  \
# 0           No  16.60       1               0      0           0   0        1
# 1           No  20.34       0               0      1           0   0        0
# 2           No  26.58       1               0      0           0   1        1
# 3           No  24.21       0               0      0           0   0        0
# 4           No  23.71       0               0      0           1   0        0
#
#   PhysicalActivity GenHealth  SleepTime Asthma
# 0                1         0          5      1
# 1                1         0          7      0
# 2                1         1          8      1
# 3                0         2          6      0
# 4                1         0          8      0

# %%
new_df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke DiffWalking Sex  \
# 0                No  16.60       1               0      0           0   0
# 1                No  20.34       0               0      1           0   0
# 2                No  26.58       1               0      0           0   1
# 3                No  24.21       0               0      0           0   0
# 4                No  23.71       0               0      0           1   0
# ...             ...    ...     ...             ...    ...         ...  ..
# 319790          Yes  27.41       1               0      0           1   1
# 319791           No  29.84       1               0      0           0   1
# 319792           No  24.24       0               0      0           0   0
# 319793           No  32.81       0               0      0           0   0
# 319794           No  46.56       0               0      0           0   0
#
#        Diabetic PhysicalActivity GenHealth  SleepTime Asthma
# ...

# %%
new_df.HeartDisease.value_counts()
plt.figure(figsize=(6,6))
sns.countplot(x='HeartDisease', data=new_df)
plt.title('Heart Disease')
plt.show()

# %%
from sklearn.datasets import make_classification
X, y = make_classification(n_classes=2, class_sep=0.5,
weights=[0.05, 0.95], n_informative=2, n_redundant=0, flip_y=0,
n_features=2, n_clusters_per_class=1, n_samples=1000, random_state=10)

# %%
from sklearn.model_selection import train_test_split
  
# split into 75:25 ratio
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
#KNN classifer
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier() 
model.fit(X_train, y_train) 
y_pred = model.predict(X_test) 
#Accuracy and Confusion matrix
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(accuracy_score(y_test, model.predict(X_test))) 
cm
# Out:
# 0.98
# array([[ 10,   5],
#        [  0, 235]], dtype=int64)

# %%
#Naive Bayes Classifier
x = new_df.drop(["HeartDisease"], axis = 1)
y = new_df.HeartDisease.values
from sklearn.model_selection import train_test_split
  
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_train, y_train)
print("Naive Bayes score: ",nb.score(x_test, y_test))
# Out:
# Naive Bayes score:  0.860817811317608

# %%
new_df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke DiffWalking Sex  \
# 0                No  16.60       1               0      0           0   0
# 1                No  20.34       0               0      1           0   0
# 2                No  26.58       1               0      0           0   1
# 3                No  24.21       0               0      0           0   0
# 4                No  23.71       0               0      0           1   0
# ...             ...    ...     ...             ...    ...         ...  ..
# 319790          Yes  27.41       1               0      0           1   1
# 319791           No  29.84       1               0      0           0   1
# 319792           No  24.24       0               0      0           0   0
# 319793           No  32.81       0               0      0           0   0
# 319794           No  46.56       0               0      0           0   0
#
#        Diabetic PhysicalActivity GenHealth  SleepTime Asthma
# ...

# %%
#split dataset in features and target variable
feature_cols = ['Smoking', 'Sex', 'BMI', 'AlcoholDrinking','Diabetic','Asthma']
X = new_df[feature_cols] # Features
y = new_df.HeartDisease	 # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
# Import Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier 
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9073578002689209
